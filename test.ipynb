# %%
# !touch config/__init__.py
# Out:
# 'touch' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import pytest
import os

# %%
from config.model_config import ModelConfig, MODEL_CONFIG
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from config.model_config import ModelConfig, MODEL_CONFIG
#
# ModuleNotFoundError: No module named 'config'

# %%
from utils.logging_config import get_logger
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from utils.logging_config import get_logger
#
# ModuleNotFoundError: No module named 'utils'

# %%
import config
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import config
#
# ModuleNotFoundError: No module named 'config'

# %%
from config.model_config import MODEL_CONFIG
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from config.model_config import MODEL_CONFIG
#
# ModuleNotFoundError: No module named 'config'

# %%
from core.models.base_llm import BaseLLM, LLMType, GenerationConfig, LLMResponse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from core.models.base_llm import BaseLLM, LLMType, GenerationConfig, LLMResponse
#
# ModuleNotFoundError: No module named 'core'
